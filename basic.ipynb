# %% [markdown]
# ## Syntax refers to the set of rules that defines the combinations and symbols that are considered to be correctly structured progrmas in a language. In another word, syntax is about the arrangement of words and code in a structured manner.

# %% [markdown]
# Symantic refers to the meaning or interpretation of symbols, caharacters and command in a language. It is about the what the code do when it supposed to runs

# %% [markdown]
# ## Basic syntaax rules in python
# ## 1 Case Sensetive - Python is case sensetive

# %%
name = "Anish"
Name = " Pallavi"

print(name)
print(Name)
# Out:
# Anish
#  Pallavi

# %%
## indentation
## Python uses indentation to define the blocks of code. Consistebt use of space or a tab is required

# %% [markdown]
# ##Indentation
# Indenation in Python is used to define the structure and hirerechy of the code. Unlinke many other programming languages that use braces{} to define the delimit blocks of code, Python uses indentation to determine tge grouping of statements. This means all the statement within a block are indented at the same level.

# %%
age =32
if age>30:
    print(age)


    print(age)
# Out:
# 32
# 32

# %%
## line continuation -- use backslash \ to continue the statenent to the next linw

total = 1+2+3+4+5+6+\
1+1+3

print(total)
# Out:
# 26

# %%
## multiple statemenfs on a single line
# vaeiable assignment
age = 32;
name = "Anish"

# %%
type(age)
type(name)
# Out:
# str

# %%
## Type Infrence
variable = 10
print(type(variable))
variable = "Pallavi"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
##  Name error
a = b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 ##  Name error
# ----> 2 a = b
#
# NameError: name 'b' is not defined

# %%
## Code examples of indentation
if True:
    print("Correct Indentation")
    if False:
        print("This wont print")
    print("This will print")
print("Outside")
# Out:
# Correct Indentation
# This will print
# Outside
