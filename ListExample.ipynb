# %% [markdown]
# ## Real  World Examples Using Lists in Python
#
# List are one of the most commomly used data structures in python, thanks to their versitility and ease of use.
# Here are saveraatal pratical examples

# %% [markdown]
# ## Example 1. Manage a To Do List

# %%
to_do_list = ["Buy Groceries","Clean the house", "Pay bills"]
## Adding to task
to_do_list.append("Schedule meeting")
to_do_list.append("Go for run")

## Removing a completed task

to_do_list.remove("Clean the house")

## checking if the task is in the list
if "Pay bills" in to_do_list:
    print("dont forget to pay the utility bills")

print("To Do  list remaning")
for task in to_do_list:
    print(f"-{task}")
# Out:
# dont forget to pay the utility bills
# To Do  list remaning
# -Buy Groceries
# -Pay bills
# -Schedule meeting
# -Go for run

# %% [markdown]
# ## Eg.2 Organising students grade
#
# Create a list to store and calculate average grades of studenrs

# %%
grades = [85,92,78,90,88]
## adding new grades
grades.append(95)

avg_grades = sum(grades)/len(grades)
print(f"Average Grade:{avg_grades: .2f}")

##Highest and lowest grades

highest_grade =max(grades)
lowest_grades = min(grades)

print(f"Highest Grades :{highest_grade}")
print(f"Lowest  grade:{lowest_grades}")
# Out:
# Average Grade: 88.00
# Highest Grades :95
# Lowest  grade:78

# %% [markdown]
# ##  Managing a inventory
#
# use a list to manage a list item in a store
