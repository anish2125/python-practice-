# %%
## Arithematic operations
a= 10
b =5
 
result = a+b
sub = a-b
mul = a*b
exponent = a**b
floor_div = a //b
print(result)
print(sub)
print(mul)
print(floor_div
)
print(exponent)
# Out:
# 15
# 5
# 50
# 2
# 100000

# %%
## Comparision operators
## == Equak to operator
a = 10
b= 10
a==b
# Out:
# True

# %%
str1 = "Anish"
str2 = "Anish"
str1 == str2
# Out:
# True

# %%
## Not eqaul to
str1 != str2
# Out:
# False

# %%
str3 = "Anish"
str4 = "anish"
str3 != str4
# Out:
# True

# %%
## greater than >
a =45
b =55
a>b
# Out:
# False

# %%
    ## less than <
a<b
# Out:
# True

# %%
## greater than or equal to
num1 = 45
num2 =45


num1>=num2
# Out:
# True

# %%
num1 <=num2
# Out:
# True

# %% [markdown]
# ### Comparision opeatror

# %%
## And , Not, OR
X = True
Y = True

result = X and Y
print(result)
# Out:
# True

# %%
## OR
X = False
Y = False

result = X or Y
print(result)
# Out:
# False

# %%
## Not 
X = True
not X
# Out:
# False

# %%
## Simple calculator

num1 = float(input("Enter the first number :"))
num2 = float(input("Enter the second number :"))

add = num1 + num2
sub = num1- num2
mul = num1 * num2
division = num1/num2
floor_div = num1//num2
modulus = num1%num2
exp = num1**num2
print(add, type(add))
print(sub, type(sub))
print(mul, type(mul))
print(division, type(division))
print(floor_div, type(floor_div) )
print(modulus, type(modulus))
# Out:
# 7.0 <class 'float'>
# 3.0 <class 'float'>
# 10.0 <class 'float'>
# 2.5 <class 'float'>
# 2.0 <class 'float'>
# 1.0 <class 'float'>
